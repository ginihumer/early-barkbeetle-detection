# %%
import tensorflow as tf
import numpy as np

# %%
model = tf.keras.models.load_model('../../Models/classification/denseNet - model.hd5')

# %%
model.load_weights('../../Models/classification/denseNet-37-0.82.hdf5')

# %%
model = tf.keras.models.load_model('test.hd5')

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            [(None, 512, 512, 3) 0
# __________________________________________________________________________________________________
# Conv1_pad (ZeroPadding2D)       (None, 513, 513, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 256, 256, 32) 864         Conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 256, 256, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 256, 256, 32) 0           bn_Conv1[0][0]
# ...

# %%
# input_layer = tf.keras.layers.InputLayer(input_shape=(480, 720, 3), name="input_1")
# model.layers[0] = input_layer

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
# Set quantize to true 
#converter.post_training_quantize=True # set true if cpu is used instead of gpu
tflite_model = converter.convert()

# %%
model = tf.keras.applications.DenseNet121()

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# %%
open('borkenkaefer_test.tflite','wb').write(tflite_model)
# Out:
# 8924080

# %%
model.summary()

# %%
# Load TFLite model and allocate tensors.
interpreter = tf.lite.Interpreter(model_path="test.tflite") 
interpreter.allocate_tensors()

# %%
# Get input and output tensors
input_details = interpreter.get_input_details() 
output_details = interpreter.get_output_details()
input_details, output_details

# %%
# Test model on random input data
input_shape = input_details[0]['shape']
input_data = np.array(np.random.random_sample(input_shape), dtype=np.float32) 
interpreter.set_tensor(input_details[0]['index'], input_data)
interpreter.invoke()
output_data = interpreter.get_tensor(output_details[0]['index']) 
print(output_data)

# %%
np.argmax(output_data)

# %%
output_data[0, np.argmax(output_data)]
